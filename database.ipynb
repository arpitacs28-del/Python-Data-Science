# %%
from sqlalchemy import create_engine,Column,Integer,String
from sqlalchemy.orm import declarative_base,sessionmaker

# %%
engine = create_engine('sqlite:///students.db')

# %%
base =  declarative_base()

# %%
class Student(base):
    __tablename__="student"
    id = Column(Integer, primary_key = True)
    name = Column(String)
    email = Column(String)
    age = Column(Integer)

# %%
base.metadata.create_all(engine)

# %%
Session = sessionmaker(bind = engine)
session = Session()

# %%
#create
student = Student(
    name = "ARPITA",
    email = "arpi123@gmail.com",
    age = 21     
)
session.add(student)
session.commit()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\engine\base.py:1969, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1968     if not evt_handled:
# -> 1969         self.dialect.do_execute(
#    1970             cursor, str_statement, effective_parameters, context
#    1971         )
#    1973 if self._has_events or self.engine._has_events:
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\engine\default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# OperationalError: database is locked
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[20], line 8
#       4     email = "arpi123@gmail.com",
#       5     age = 21
#       6 )
#       7 session.add(student)
# ----> 8 session.commit()
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\orm\session.py:2035, in Session.commit(self)
#    2032 if trans is None:
#    2033     trans = self._autobegin_t()
# -> 2035 trans.commit(_to_root=True)
#
# File <string>:2, in commit(self, _to_root)
#       1 'Could not get source, probably due dynamically evaluated source code.'
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\orm\state_changes.py:137, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     135 self._next_state = _StateChangeStates.CHANGE_IN_PROGRESS
#     136 try:
# --> 137     ret_value = fn(self, *arg, **kw)
#     138 except:
#     139     raise
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\orm\session.py:1316, in SessionTransaction.commit(self, _to_root)
#    1314 if self._state is not SessionTransactionState.PREPARED:
#    1315     with self._expect_state(SessionTransactionState.PREPARED):
# -> 1316         self._prepare_impl()
#    1318 if self._parent is None or self.nested:
#    1319     for conn, trans, should_commit, autoclose in set(
#    1320         self._connections.values()
#    1321     ):
#
# File <string>:2, in _prepare_impl(self)
#       1 'Could not get source, probably due dynamically evaluated source code.'
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\orm\state_changes.py:137, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     135 self._next_state = _StateChangeStates.CHANGE_IN_PROGRESS
#     136 try:
# --> 137     ret_value = fn(self, *arg, **kw)
#     138 except:
#     139     raise
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\orm\session.py:1290, in SessionTransaction._prepare_impl(self)
#    1288     if self.session._is_clean():
#    1289         break
# -> 1290     self.session.flush()
#    1291 else:
#    1292     raise exc.FlushError(
#    1293         "Over 100 subsequent flushes have occurred within "
#    1294         "session.commit() - is an after_flush() hook "
#    1295         "creating new objects?"
#    1296     )
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\orm\session.py:4353, in Session.flush(self, objects)
#    4351 try:
#    4352     self._flushing = True
# -> 4353     self._flush(objects)
#    4354 finally:
#    4355     self._flushing = False
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\orm\session.py:4488, in Session._flush(self, objects)
#    4485     transaction.commit()
#    4487 except:
# -> 4488     with util.safe_reraise():
#    4489         transaction.rollback(_capture_exception=True)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\util\langhelpers.py:122, in safe_reraise.__exit__(self, type_, value, traceback)
#     120     assert exc_value is not None
#     121     self._exc_info = None  # remove potential circular references
# --> 122     raise exc_value.with_traceback(exc_tb)
#     123 else:
#     124     self._exc_info = None  # remove potential circular references
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\orm\session.py:4449, in Session._flush(self, objects)
#    4447 self._warn_on_events = True
#    4448 try:
# -> 4449     flush_context.execute()
#    4450 finally:
#    4451     self._warn_on_events = False
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\orm\unitofwork.py:465, in UOWTransaction.execute(self)
#     463 else:
#     464     for rec in topological.sort(self.dependencies, postsort_actions):
# --> 465         rec.execute(self)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\orm\unitofwork.py:641, in SaveUpdateAll.execute(self, uow)
#     639 @util.preload_module("sqlalchemy.orm.persistence")
#     640 def execute(self, uow):
# --> 641     util.preloaded.orm_persistence.save_obj(
#     642         self.mapper,
#     643         uow.states_for_mapper_hierarchy(self.mapper, False, False),
#     644         uow,
#     645     )
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\orm\persistence.py:94, in save_obj(base_mapper, states, uowtransaction, single)
#      82     update = _collect_update_commands(
#      83         uowtransaction, table, states_to_update
#      84     )
#      86     _emit_update_statements(
#      87         base_mapper,
#      88         uowtransaction,
#    (...)     91         update,
#      92     )
# ---> 94     _emit_insert_statements(
#      95         base_mapper,
#      96         uowtransaction,
#      97         mapper,
#      98         table,
#      99         insert,
#     100     )
#     102 _finalize_insert_update_commands(
#     103     base_mapper,
#     104     uowtransaction,
#    (...)    120     ),
#     121 )
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\orm\persistence.py:1234, in _emit_insert_statements(base_mapper, uowtransaction, mapper, table, insert, bookkeeping, use_orm_insert_stmt, execution_options)
#    1228     result = connection.execute(
#    1229         statement.values(value_params),
#    1230         params,
#    1231         execution_options=execution_options,
#    1232     )
#    1233 else:
# -> 1234     result = connection.execute(
#    1235         statement,
#    1236         params,
#    1237         execution_options=execution_options,
#    1238     )
#    1240 primary_key = result.inserted_primary_key
#    1241 if primary_key is None:
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\engine\base.py:1421, in Connection.execute(self, statement, parameters, execution_options)
#    1419     raise exc.ObjectNotExecutableError(statement) from err
#    1420 else:
# -> 1421     return meth(
#    1422         self,
#    1423         distilled_parameters,
#    1424         execution_options or NO_OPTIONS,
#    1425     )
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\sql\elements.py:526, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     524     if TYPE_CHECKING:
#     525         assert isinstance(self, Executable)
# --> 526     return connection._execute_clauseelement(
#     527         self, distilled_params, execution_options
#     528     )
#     529 else:
#     530     raise exc.ObjectNotExecutableError(self)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\engine\base.py:1643, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1631 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1632     "compiled_cache", self.engine._compiled_cache
#    1633 )
#    1635 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1636     dialect=dialect,
#    1637     compiled_cache=compiled_cache,
#    (...)   1641     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1642 )
# -> 1643 ret = self._execute_context(
#    1644     dialect,
#    1645     dialect.execution_ctx_cls._init_compiled,
#    1646     compiled_sql,
#    1647     distilled_parameters,
#    1648     execution_options,
#    1649     compiled_sql,
#    1650     distilled_parameters,
#    1651     elem,
#    1652     extracted_params,
#    1653     cache_hit=cache_hit,
#    1654 )
#    1655 if has_events:
#    1656     self.dispatch.after_execute(
#    1657         self,
#    1658         elem,
#    (...)   1662         ret,
#    1663     )
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\engine\base.py:1848, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1846     return self._exec_insertmany_context(dialect, context)
#    1847 else:
# -> 1848     return self._exec_single_context(
#    1849         dialect, context, statement, parameters
#    1850     )
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\engine\base.py:1988, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1985     result = context._setup_result_proxy()
#    1987 except BaseException as e:
# -> 1988     self._handle_dbapi_exception(
#    1989         e, str_statement, effective_parameters, cursor, context
#    1990     )
#    1992 return result
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\engine\base.py:2365, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2363 elif should_wrap:
#    2364     assert sqlalchemy_exception is not None
# -> 2365     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2366 else:
#    2367     assert exc_info[1] is not None
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\engine\base.py:1969, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1967                 break
#    1968     if not evt_handled:
# -> 1969         self.dialect.do_execute(
#    1970             cursor, str_statement, effective_parameters, context
#    1971         )
#    1973 if self._has_events or self.engine._has_events:
#    1974     self.dispatch.after_cursor_execute(
#    1975         self,
#    1976         cursor,
#    (...)   1980         context.executemany,
#    1981     )
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\engine\default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# OperationalError: (sqlite3.OperationalError) database is locked
# [SQL: INSERT INTO student (name, email, age) VALUES (?, ?, ?)]
# [parameters: ('ARPITA', 'arpi123@gmail.com', 21)]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
#create
student = Student(
    name = "ADEEBA",
    email = "ade123@gmail.com",
    age = 21     
)
session.add(student)
session.commit()

# %%
#retrival
students = session.query(Student).all()
for student in students:
    print(student.name)
# Out:
# ADEEBA
# ARPITA
# ADEEBA

# %%
#update
students = session.query(Student).filter_by(id=1).first()
student.age = 32
session.commit
# Out:
# ---------------------------------------------------------------------------
# PendingRollbackError                      Traceback (most recent call last)
# Cell In[21], line 2
#       1 #update
# ----> 2 students = session.query(Student).filter_by(id=1).first()
#       3 student.age = 32
#       4 session.commit
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\orm\query.py:2766, in Query.first(self)
#    2764     return self._iter().first()  # type: ignore
#    2765 else:
# -> 2766     return self.limit(1)._iter().first()
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\orm\query.py:2864, in Query._iter(self)
#    2861 params = self._params
#    2863 statement = self._statement_20()
# -> 2864 result: Union[ScalarResult[_T], Result[_T]] = self.session.execute(
#    2865     statement,
#    2866     params,
#    2867     execution_options={"_sa_orm_load_options": self.load_options},
#    2868 )
#    2870 # legacy: automatically set scalars, unique
#    2871 if result._attributes.get("is_single_entity", False):
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\orm\session.py:2373, in Session.execute(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event)
#    2313 def execute(
#    2314     self,
#    2315     statement: Executable,
#    (...)   2321     _add_event: Optional[Any] = None,
#    2322 ) -> Result[Any]:
#    2323     r"""Execute a SQL expression construct.
#    2324
#    2325     Returns a :class:`_engine.Result` object representing
#    (...)   2371
#    2372     """
# -> 2373     return self._execute_internal(
#    2374         statement,
#    2375         params,
#    2376         execution_options=execution_options,
#    2377         bind_arguments=bind_arguments,
#    2378         _parent_execute_state=_parent_execute_state,
#    2379         _add_event=_add_event,
#    2380     )
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\orm\session.py:2261, in Session._execute_internal(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event, _scalar_result)
#    2247     (
#    2248         statement,
#    2249         execution_options,
#    (...)   2256         False,
#    2257     )
#    2259 bind = self.get_bind(**bind_arguments)
# -> 2261 conn = self._connection_for_bind(bind)
#    2263 if _scalar_result and not compile_state_cls:
#    2264     if TYPE_CHECKING:
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\orm\session.py:2113, in Session._connection_for_bind(self, engine, execution_options, **kw)
#    2111 if trans is None:
#    2112     trans = self._autobegin_t()
# -> 2113 return trans._connection_for_bind(engine, execution_options)
#
# File <string>:2, in _connection_for_bind(self, bind, execution_options)
#       1 'Could not get source, probably due dynamically evaluated source code.'
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\orm\state_changes.py:101, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#      95 current_state = self._state
#      97 if (
#      98     has_prerequisite_states
#      99     and current_state not in prerequisite_state_collection
#     100 ):
# --> 101     self._raise_for_prerequisite_state(fn.__name__, current_state)
#     103 next_state = self._next_state
#     104 existing_fn = self._current_fn
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\orm\session.py:975, in SessionTransaction._raise_for_prerequisite_state(self, operation_name, state)
#     973 if state is SessionTransactionState.DEACTIVE:
#     974     if self._rollback_exception:
# --> 975         raise sa_exc.PendingRollbackError(
#     976             "This Session's transaction has been rolled back "
#     977             "due to a previous exception during flush."
#     978             " To begin a new transaction with this Session, "
#     979             "first issue Session.rollback()."
#     980             f" Original exception was: {self._rollback_exception}",
#     981             code="7s2a",
#     982         )
#     983     else:
#     984         raise sa_exc.InvalidRequestError(
#     985             "This session is in 'inactive' state, due to the "
#     986             "SQL transaction being rolled back; no further SQL "
#     987             "can be emitted within this transaction."
#     988         )
#
# PendingRollbackError: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (sqlite3.OperationalError) database is locked
# [SQL: INSERT INTO student (name, email, age) VALUES (?, ?, ?)]
# [parameters: ('ARPITA', 'arpi123@gmail.com', 21)]
# (Background on this error at: https://sqlalche.me/e/20/e3q8) (Background on this error at: https://sqlalche.me/e/20/7s2a)

# %%
students = session.query(Student).all()
for student in students:
    print(student.age)
# Out:
# 32
# 21
# 32

# %%
student = session.query(Student).filter_by(id=1).first()
session.delete(student)
session.commit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\orm\session.py:3546, in Session.delete(self, instance)
#    3545 try:
# -> 3546     state = attributes.instance_state(instance)
#    3547 except exc.NO_STATE as err:
#
# AttributeError: 'NoneType' object has no attribute '_sa_instance_state'
#
# The above exception was the direct cause of the following exception:
#
# UnmappedInstanceError                     Traceback (most recent call last)
# Cell In[13], line 2
#       1 student = session.query(Student).filter_by(id=1).first()
# ----> 2 session.delete(student)
#       3 session.commit()
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\orm\session.py:3548, in Session.delete(self, instance)
#    3546     state = attributes.instance_state(instance)
#    3547 except exc.NO_STATE as err:
# -> 3548     raise exc.UnmappedInstanceError(instance) from err
#    3550 self._delete_impl(state, instance, head=True)
#
# UnmappedInstanceError: Class 'builtins.NoneType' is not mapped

# %%
#login
email = input("enter email:")
name = input("enter name:")

user = session.query(Student).filter_by(email = email).first()

if user:
    if user.name == name:
        print("Login successful")
    else:
        print("Invalid username")
else:
    print("User not found")
# Out:
# Login successful
